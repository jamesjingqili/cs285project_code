# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
all_returns = np.load("/Users/gavenma/Documents/GitHub/cs285_final_project/code/slbo/all_returns.npy")

# %%
fig = plt.figure()

for i in range(all_returns.shape[0]):
    plt.plot(np.arange(all_returns.shape[1]), all_returns[i,:])

plt.legend(['task '+str(i+1) for i in range(all_returns.shape[0])])
plt.ylabel('Reward')
plt.xlabel('Training iteration')
plt.show()

# %%
all_returns[0,:]
['task '+str(i) for i in range(5)]
# Out:
# ['task 0', 'task 1', 'task 2', 'task 3', 'task 4']
